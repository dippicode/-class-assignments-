# %%
import pandas as pd
from ast import literal_eval
import requests

# %%
import ast

# %%
url='https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48088',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48088/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48088/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48088/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48088',
#   'id': 1339225246,
#   'node_id': 'PR_kwDOAA0YD849MYFH',
#   'number': 48088,
#   'title': 'ENH: move an exception and add a prehook to check for exception place…',
#   'user': {'login': 'dataxerik',
#    'id': 15721311,
#    'node_id': 'MDQ6VXNlcjE1NzIxMzEx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15721311?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dataxerik',
#    'html_url': 'https://github.com/dataxerik',
#    'followers_url': 'https://api.github.com/users/dataxerik/followers',
#    'following_url': 'https://api.github.com/users/dataxerik/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dataxerik/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dataxerik/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dataxerik/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dataxerik/orgs',
#    'repos_url': 'https://api.github.com/users/dataxerik/repos',
#    'events_url': 'https://api.github.com/users/dataxerik/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dataxerik/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-15T16:49:51Z',
#   'updated_at': '2022-08-15T16:49:51Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48088',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48088',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48088.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48088.patch',
#    'merged_at': None},
#   'body': "- [x] closes xref #27656.\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nThis is a follow up from my last MR: https://github.com/pandas-dev/pandas/pull/47901. I'm new to prehooks, so I may have went in the wrong direction for the prehook. But, I was thinking of checking the files for class that inherit Exceptions and flagging them. Let me know if another approach is preferred.\r\n\r\nI also noticed some other exceptions while working on this.\r\n\r\n- InvalidVersion looked like an error a user might see so I moved it to errors/__init__.py\r\n- LossySetitemError, NoBufferPresent, and InvalidComparison. I wasn't sure about; they're in core and it didn't seem that the user would see them, so I left them as is and had the hook ignore them\r\n- NotThisMethod. It seem like a code generated exception rather than a custom pandas one, so I excluded that from the hook\r\n- OptionError: In the initial issue, there was a comment about keeping OptionError in _config, so I excluded that from the hook",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48088/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48088/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48087',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48087/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48087/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48087/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48087',
#   'id': 1339162046,
#   'node_id': 'PR_kwDOAA0YD849MKt0',
#   'number': 48087,
#   'title': 'ENH: Make categories setitem error more readable',
#   'user': {'login': 'daspartho',
#    'id': 59410571,
#    'node_id': 'MDQ6VXNlcjU5NDEwNTcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59410571?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daspartho',
#    'html_url': 'https://github.com/daspartho',
#    'followers_url': 'https://api.github.com/users/daspartho/followers',
#    'following_url': 'https://api.github.com/users/daspartho/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/daspartho/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/daspartho/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/daspartho/subscriptions',
#    'organizations_url': 'https://api.github.com/users/daspartho/orgs',
#    'repos_url': 'https://api.github.com/users/daspartho/repos',
#    'events_url': 'https://api.github.com/users/daspartho/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/daspartho/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-15T15:46:16Z',
#   'updated_at': '2022-08-15T15:46:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48087',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48087',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48087.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48087.patch',
#    'merged_at': None},
#   'body': '- [X] closes #46646\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48087/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48087/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48086',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48086/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48086/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48086/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48086',
#   'id': 1338939436,
#   'node_id': 'I_kwDOAA0YD85Pzpgs',
#   'number': 48086,
#   'title': 'ENH: add `regex=False` option to pandas.Series.str.match and fullmatch (like in str.contains)',
#   'user': {'login': 'robna',
#    'id': 26489593,
#    'node_id': 'MDQ6VXNlcjI2NDg5NTkz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26489593?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/robna',
#    'html_url': 'https://github.com/robna',
#    'followers_url': 'https://api.github.com/users/robna/followers',
#    'following_url': 'https://api.github.com/users/robna/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/robna/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/robna/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/robna/subscriptions',
#    'organizations_url': 'https://api.github.com/users/robna/orgs',
#    'repos_url': 'https://api.github.com/users/robna/repos',
#    'events_url': 'https://api.github.com/users/robna/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/robna/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-15T12:27:14Z',
#   'updated_at': '2022-08-15T12:27:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [X] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\npandas.Series.str.contains accepts the parameter `regex` which is a boolean defaulting to True, meaning that the provided pattern is treated as a regex expression. It is useful that this behaviour can be turned of, for instance if one tries to match a string which contains parentheses (which would be interpreted as regex groups)\r\n\r\nExample:\r\n\r\n`pd.Series.str.match('AB(CD EF)')` would be interpreted as regex with groups\r\n\r\n...same for `pd.Series.str.fullmatch('AB(CD EF)')`. This is not always wanted. I.e. I would like to do a fullmatch on the literal string `'AB(CD EF)'`\r\n\r\nIt would work with: `pd.Series.str.contains('AB(CD EF)', regex=False)`, but then of course the matching is less strict.\n\n### Feature Description\n\nI don't know if its possible this way but perhaps copy how pd.Series.str.contains works with `regex=False` in the [pandas/core/strings/accessor.py](https://github.com/pandas-dev/pandas/commit/638a42fcc2acd66f75ac589a031dd533d5cbdd53#diff-b561abce692e1f6b2fb34ee594893c19ebb1694949d4398cc25f535fb133c943)\n\n### Alternative Solutions\n\nAn alternative might by to escape relevant characters to avoid interpretation as regex control symbols. But this becomes unpractical if the match string is not directly entered as a string but obtained from a variable which contents are not fixed. Or when its used within a loop.\n\n### Additional Context\n\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48086/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48086/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48085',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48085/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48085/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48085/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48085',
#   'id': 1338930777,
#   'node_id': 'PR_kwDOAA0YD849LZMW',
#   'number': 48085,
#   'title': 'ENH: Add axis parameter to add_prefix and add_suffix',
#   'user': {'login': 'dannyi96',
#    'id': 15380498,
#    'node_id': 'MDQ6VXNlcjE1MzgwNDk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15380498?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dannyi96',
#    'html_url': 'https://github.com/dannyi96',
#    'followers_url': 'https://api.github.com/users/dannyi96/followers',
#    'following_url': 'https://api.github.com/users/dannyi96/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dannyi96/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dannyi96/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dannyi96/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dannyi96/orgs',
#    'repos_url': 'https://api.github.com/users/dannyi96/repos',
#    'events_url': 'https://api.github.com/users/dannyi96/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dannyi96/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-15T12:18:17Z',
#   'updated_at': '2022-08-15T15:19:39Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48085',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48085',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48085.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48085.patch',
#    'merged_at': None},
#   'body': '- [X] closes #47819\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48085/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48085/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48084',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48084/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48084/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48084/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48084',
#   'id': 1338925716,
#   'node_id': 'I_kwDOAA0YD85PzmKU',
#   'number': 48084,
#   'title': 'ENH: alleviate issues with inconsistent multi-level joining on a 0-column merge table',
#   'user': {'login': 'prhbrt',
#    'id': 7011110,
#    'node_id': 'MDQ6VXNlcjcwMTExMTA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7011110?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/prhbrt',
#    'html_url': 'https://github.com/prhbrt',
#    'followers_url': 'https://api.github.com/users/prhbrt/followers',
#    'following_url': 'https://api.github.com/users/prhbrt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/prhbrt/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/prhbrt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/prhbrt/subscriptions',
#    'organizations_url': 'https://api.github.com/users/prhbrt/orgs',
#    'repos_url': 'https://api.github.com/users/prhbrt/repos',
#    'events_url': 'https://api.github.com/users/prhbrt/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/prhbrt/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-15T12:12:58Z',
#   'updated_at': '2022-08-15T15:31:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [X] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\n    FutureWarning: merging between different levels is deprecated and will be removed in a future version. (`some number` levels on the left, 1 on the right)\r\n\r\nWhen running:\r\n\r\n    multilevel_columns = pd.DataFrame({('a', 'b'): np.random.randint(0,100, 10)})\r\n    multilevel_columns.index.name = 'alpha'\r\n\r\n    relations = pd.DataFrame({\r\n        'alpha': np.random.randint(0,10, 10),\r\n        'beta': np.random.randint(0,10, 10)\r\n    }).set_index(['alpha', 'beta'])\r\n\r\n    multilevel_columns.join(relations)\r\n\r\nbecause the 0-column merge table `relations` only has 1 column-level, whereas `multilevel_columns` has two. However, it's irrelevant because `relations` has 0 columns anyway, and so concatenating them should be trivial.\r\n\n\n### Feature Description\n\nAllow merging inconsistent levels if one frame has 0 columns.\n\n### Alternative Solutions\n\nChange [this check](https://github.com/pandas-dev/pandas/blob/c8fc47ba714f9ac181905f4d9674b4a43772e833/pandas/core/reshape/merge.py#L665) with the added condition `and len(_left.columns) > 0 and len(_right.columns) > 0`\n\n### Additional Context\n\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48084/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48084/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48083',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48083/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48083/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48083/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48083',
#   'id': 1338463791,
#   'node_id': 'I_kwDOAA0YD85Px1Yv',
#   'number': 48083,
#   'title': 'BUG: pd.cut creates NaNs instead of expected bins for Timestamps. Behaviour is DIFFERENT for list and Series, with IntervalIndex and DatetimeIndex',
#   'user': {'login': 'VladimirFokow',
#    'id': 57260995,
#    'node_id': 'MDQ6VXNlcjU3MjYwOTk1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57260995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VladimirFokow',
#    'html_url': 'https://github.com/VladimirFokow',
#    'followers_url': 'https://api.github.com/users/VladimirFokow/followers',
#    'following_url': 'https://api.github.com/users/VladimirFokow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/VladimirFokow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/VladimirFokow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/VladimirFokow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/VladimirFokow/orgs',
#    'repos_url': 'https://api.github.com/users/VladimirFokow/repos',
#    'events_url': 'https://api.github.com/users/VladimirFokow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/VladimirFokow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-15T02:40:05Z',
#   'updated_at': '2022-08-15T02:51:25Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nts = pd.Series([pd.Timestamp(\'2000-01-01\'),\r\n                pd.Timestamp(\'2000-01-02\'),\r\n                pd.Timestamp(\'2000-01-02\'),\r\n                pd.Timestamp(\'2000-01-03\')])\r\nbins = pd.interval_range(ts[0], ts[3])\r\n\r\n# 1) `IntervalIndex` with `pd.Series`:\r\npd.cut(ts, bins)\r\n```\r\nOutput:\r\n```\r\n0    NaN\r\n1    NaN\r\n2    NaN\r\n3    NaN\r\ndtype: category\r\nCategories (2, interval[datetime64[ns], right]): [(2000-01-01, 2000-01-02] < (2000-01-02, 2000-01-03]]\r\n```\r\n\r\n```python\r\n# 2) `IntervalIndex` with `np.ndarray`:\r\npd.cut(ts.to_numpy(), bins)\r\n```\r\nOutput:\r\n```\r\n[NaN, NaN, NaN, NaN]\r\nCategories (2, interval[datetime64[ns], right]): [(2000-01-01, 2000-01-02] < (2000-01-02, 2000-01-03]]\r\n```\r\n\r\n```python\r\n# 3) `DatetimeIndex` with list:\r\ndt_indices = pd.date_range(ts[0], ts[3])\r\npd.cut(ts.to_list(), dt_indices)  # <-- produces TypeError\r\n```\r\nTypeError:\r\n```python-traceback\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\n/Users/Vladimir/nb.ipynb Cell 30 in <cell line: 1>()\r\n----> 1 pd.cut(ts.to_list(), dt_indices)\r\n\r\nFile ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/core/reshape/tile.py:292, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)\r\n    289     if (np.diff(bins.astype("float64")) < 0).any():\r\n    290         raise ValueError("bins must increase monotonically.")\r\n--> 292 fac, bins = _bins_to_cuts(\r\n    293     x,\r\n    294     bins,\r\n    295     right=right,\r\n    296     labels=labels,\r\n    297     precision=precision,\r\n    298     include_lowest=include_lowest,\r\n    299     dtype=dtype,\r\n    300     duplicates=duplicates,\r\n    301     ordered=ordered,\r\n    302 )\r\n    304 return _postprocess_for_cut(fac, bins, retbins, dtype, original)\r\n\r\nFile ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/core/reshape/tile.py:427, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)\r\n    424         bins = unique_bins\r\n    426 side: Literal["left", "right"] = "left" if right else "right"\r\n--> 427 ids = ensure_platform_int(bins.searchsorted(x, side=side))\r\n    429 if include_lowest:\r\n    430     ids[np.asarray(x) == bins[0]] = 1\r\n\r\nTypeError: \'<\' not supported between instances of \'int\' and \'Timestamp\'\r\n```\r\n\r\n\r\n\r\n### Issue Description\r\n\r\n* If `bins` is an `IntervalIndex`: `pd.cut` works as expected when `x` is a list of Timestamps, but produces `NaN`s when it is a `pd.Series` or `np.ndarray`.\r\n* If `bins` is a `DatetimeIndex `: `pd.cut` works as expected when `x` is a `pd.Series` or `np.ndarray` of Timestamps, but raises a `TypeError` when it is a list.\r\n\r\n[`pd.cut` documentation](https://pandas.pydata.org/docs/reference/api/pandas.cut.html) clearly states that `x` can be any 1-dimensional array-like.\r\n\r\n\r\n#### Examples that work as expected:\r\n\r\n```python\r\npd.cut(ts.to_list(), bins)\r\npd.cut(ts, dt_indices)\r\npd.cut(ts.to_numpy(), dt_indices)\r\n```\r\n\r\n[This issue is a question on Stack Overflow](https://stackoverflow.com/q/73354672/14627505).\r\n\r\n\r\n### Expected Behavior\r\n\r\n```python\r\n[NaN, (2000-01-01, 2000-01-02], (2000-01-01, 2000-01-02], (2000-01-02, 2000-01-03]]\r\n```\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : e8093ba372f9adfe79439d90fe74b0b5b6dea9d6\r\npython        ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48083/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48083/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48082',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48082/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48082/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48082/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48082',
#   'id': 1338436936,
#   'node_id': 'PR_kwDOAA0YD849Julc',
#   'number': 48082,
#   'title': 'REF: avoid internals in merge code',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-15T01:53:35Z',
#   'updated_at': '2022-08-15T14:47:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48082',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48082',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48082.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48082.patch',
#    'merged_at': None},
#   'body': 'After this, concatenate_block_managers is only used in one place.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48082/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48082/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48081',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48081/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48081/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48081/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48081',
#   'id': 1338338567,
#   'node_id': 'PR_kwDOAA0YD849JaVt',
#   'number': 48081,
#   'title': 'ENH: Add support for groupby.ohlc for ea dtypes',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-14T20:10:41Z',
#   'updated_at': '2022-08-14T20:53:46Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48081',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48081',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48081.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48081.patch',
#    'merged_at': None},
#   'body': '- [x] xref #37493 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis did not work at all before\r\n\r\ncc @jorisvandenbossche ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48081/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48081/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48080',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48080/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48080/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48080/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48080',
#   'id': 1338247223,
#   'node_id': 'PR_kwDOAA0YD849JJG0',
#   'number': 48080,
#   'title': 'PDEP-3: Small data visualization consolidation',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2301354,
#     'node_id': 'MDU6TGFiZWwyMzAxMzU0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Data',
#     'name': 'IO Data',
#     'color': '06909A',
#     'default': False,
#     'description': "IO issues that don't fit into a more specific label"},
#    {'id': 2413328,
#     'node_id': 'MDU6TGFiZWwyNDEzMzI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Visualization',
#     'name': 'Visualization',
#     'color': '8AE234',
#     'default': False,
#     'description': None},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'},
#    {'id': 4253279386,
#     'node_id': 'LA_kwDOAA0YD879g-Sa',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/PDEP',
#     'name': 'PDEP',
#     'color': '4B02F8',
#     'default': False,
#     'description': 'pandas enhancement proposal'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-08-14T13:29:20Z',
#   'updated_at': '2022-08-14T20:26:52Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48080',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48080',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48080.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48080.patch',
#    'merged_at': None},
#   'body': 'This is the official Pdep and design objectives I have been unofficially publishing PRs towards.\r\n\r\nSome items like reimplementing `DataFrame.to_html` and `DataFrame.to_latex` to use `jinja2` suffer from ad-hoc and inconsistent PRs and PR reviews. It seems appropriate for a wider discussion and either adoption or rejection of these concepts.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48080/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48080/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48079',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48079/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48079/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48079/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48079',
#   'id': 1338203399,
#   'node_id': 'I_kwDOAA0YD85Pw10H',
#   'number': 48079,
#   'title': 'ENH: Move column levels in multi column index to another position',
#   'user': {'login': 'andreas-vester',
#    'id': 29901736,
#    'node_id': 'MDQ6VXNlcjI5OTAxNzM2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29901736?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreas-vester',
#    'html_url': 'https://github.com/andreas-vester',
#    'followers_url': 'https://api.github.com/users/andreas-vester/followers',
#    'following_url': 'https://api.github.com/users/andreas-vester/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/andreas-vester/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/andreas-vester/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/andreas-vester/subscriptions',
#    'organizations_url': 'https://api.github.com/users/andreas-vester/orgs',
#    'repos_url': 'https://api.github.com/users/andreas-vester/repos',
#    'events_url': 'https://api.github.com/users/andreas-vester/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/andreas-vester/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None},
#    {'id': 2365504893,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0ODkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Closing%20Candidate',
#     'name': 'Closing Candidate',
#     'color': 'be21f2',
#     'default': False,
#     'description': 'May be closeable, needs more eyeballs'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-08-14T10:49:18Z',
#   'updated_at': '2022-08-15T16:20:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [X] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nI am looking for a way to move a certain level within a multi column index to another position.\r\n\r\nLet\'s say I have the following dataframe:\r\n\r\n    unknown_level_name_0     a1            \r\n    unknown_level_name_1     b1      b2    \r\n    known_level_name         x1      x1    \r\n    unknown_level_name_last  c1  c1  c1  c1\r\n    0                        37  34  97  19\r\n    1                        54  47  53  46\r\n    2                        63  94  14  85\r\n    3                        16  51  27  96\r\n    4                        32  64  76  26\r\n\r\nUsually, I would try to use ``reorder_levels`` or ``swaplevels``, however, this is not possible or at least somewhat complicated if you don\'t know the exact index position of the level that you want to move. The only thing you know is the name of the index level.\r\n\r\nLet\'s assume, the desired outcome is to move the ``known_level_name`` to the very top. The result should then look like this:\r\n\r\n\r\n    known_level_name         x1      x1    \r\n    unknown_level_name_0     a1            \r\n    unknown_level_name_1     b1      b2    \r\n    unknown_level_name_last  c1  c1  c1  c1\r\n    0                        37  34  97  19\r\n    1                        54  47  53  46\r\n    2                        63  94  14  85\r\n    3                        16  51  27  96\r\n    4                        32  64  76  26\n\n### Feature Description\n\nRight now, I am using the following function to solve this problem:\r\n\r\n```\r\ndef move_level(df: pd.DataFrame, column_level: Union[str, int], new_pos: int=0) -> pd.DataFrame:\r\n    """\r\n    Moves column level to new position.\r\n\r\n    Parameters\r\n    ---------------\r\n    df\r\n        DataFrame with multi-column index\r\n    column_level\r\n        Column level to be moved.\r\n    new_pos\r\n        New column index level position.\r\n\r\n    Returns\r\n    -----------\r\n    pd.DataFrame\r\n        DataFrame with reordered multi column index.\r\n\r\n    Raises\r\n    ---------\r\n    IndexError\r\n        IndexError will be raised if `column_level` doesn\'t exist.\r\n\r\n    """\r\n    if column_level in df.columns.names:\r\n        idx = df.columns.names.index(column_level)\r\n    elif isinstance(column_level, int) and -len(df.columns.names) <= column_level < len(df.columns.names):\r\n        idx = column_level\r\n    else:\r\n        raise IndexError(f"Invalid index \'{column_level}\'")\r\n\r\n    order = list(range(len(df.columns.names)))\r\n\r\n    # translate new_pos just in case it is a negative index\r\n    new_pos = order.index(order[new_pos])\r\n\r\n    # remove list element\r\n    order.pop(idx)\r\n\r\n    # insert list element to new position\r\n    order.insert(new_pos, idx)\r\n\r\n    # finally, sort multi column index according to \'order\' and return\r\n    return df.reorder_levels(order=order, axis=1)\r\n```\n\n### Alternative Solutions\n\nI raised this question at https://stackoverflow.com/questions/71514091/move-column-level-to-top-in-multi-column-index-pandas-dataframe.\n\n### Additional Context\n\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48079/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48079/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48078',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48078/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48078/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48078/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48078',
#   'id': 1338193822,
#   'node_id': 'PR_kwDOAA0YD849I_8f',
#   'number': 48078,
#   'title': 'ENH: Support mask for groupby var and mean',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-14T10:11:09Z',
#   'updated_at': '2022-08-14T15:54:06Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48078',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48078',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48078.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48078.patch',
#    'merged_at': None},
#   'body': '- [x] xref #37493 (Replace xxxx with the Github issue number)\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis saves around 30-35% in the aggregation operation for nullable dtypes with 1/3 missing values compared to the previous implementation\r\n\r\ncc @jorisvandenbossche ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48078/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48078/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48077',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48077/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48077/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48077/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48077',
#   'id': 1338158775,
#   'node_id': 'PR_kwDOAA0YD849I5RB',
#   'number': 48077,
#   'title': 'Bug: Unexpected behavior when assigning multi-dimensional array to DataFrame column ',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-14T07:24:35Z',
#   'updated_at': '2022-08-15T12:39:20Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48077',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48077',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48077.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48077.patch',
#    'merged_at': None},
# ...
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-08-12T10:48:08Z',
#   'updated_at': '2022-08-14T16:44:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48055',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48055',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48055.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48055.patch',
#    'merged_at': None},
#   'body': "When you run python` ./scripts/validate_docstrings.py --errors=PR02`, one of the errors is `/home/pandas/pandas/io/formats/style.py:3144:PR02:pandas.io.formats.style.Styler.text_gradient:Unknown parameters {'text_color_threshold'}`\r\n\r\nThe error I believe was because the function text_gradient was using the doc-string for background gradient, which had text_color_threshold as one of the parameters, so validate doc-string expected text_gradient to also have text_color_threshold, even though that parameter was not intended for text_gradient.\r\n\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48055/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48055/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48052',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48052/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48052/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48052/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48052',
#   'id': 1336615868,
#   'node_id': 'I_kwDOAA0YD85PqyO8',
#   'number': 48052,
#   'title': 'BUG: Weird Behavior of astype(bool) for np.nan',
#   'user': {'login': 'redreamality',
#    'id': 3147776,
#    'node_id': 'MDQ6VXNlcjMxNDc3NzY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3147776?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/redreamality',
#    'html_url': 'https://github.com/redreamality',
#    'followers_url': 'https://api.github.com/users/redreamality/followers',
#    'following_url': 'https://api.github.com/users/redreamality/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/redreamality/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/redreamality/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/redreamality/subscriptions',
#    'organizations_url': 'https://api.github.com/users/redreamality/orgs',
#    'repos_url': 'https://api.github.com/users/redreamality/repos',
#    'events_url': 'https://api.github.com/users/redreamality/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/redreamality/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'},
#    {'id': 2533668378,
#     'node_id': 'MDU6TGFiZWwyNTMzNjY4Mzc4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Upstream%20issue',
#     'name': 'Upstream issue',
#     'color': 'd8439a',
#     'default': False,
#     'description': 'Issue related to pandas dependency'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-12T00:19:39Z',
#   'updated_at': '2022-08-12T16:50:52Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport numpy as np\r\n\r\nprint(pd.DataFrame([np.nan,0,1,[],None]).astype(bool))\n```\n\n\n### Issue Description\n\n       0\r\n0   True\r\n1  False\r\n2   True\r\n3  False\r\n4  False\n\n### Expected Behavior\n\n       0\r\n0  False\r\n1   True\r\n2   True\r\n3  False\r\n4  False\n\n### Installed Versions\n\n<details>\r\n>>> pd.__version__\r\n\'1.4.2\'\r\n>>> pd.show_versions()\r\nC:\\tools\\Anaconda3\\lib\\site-packages\\_distutils_hack\\__init__.py:17: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.\r\n  warnings.warn(\r\nC:\\tools\\Anaconda3\\lib\\site-packages\\_distutils_hack\\__init__.py:30: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "C:\\tools\\Anaconda3\\lib\\site-packages\\pandas\\util\\_print_versions.py", line 109, in show_versions\r\n    deps = _get_dependency_info()\r\n  File "C:\\tools\\Anaconda3\\lib\\site-packages\\pandas\\util\\_print_versions.py", line 88, in _get_dependency_info\r\n    mod = import_optional_dependency(modname, errors="ignore")\r\n  File "C:\\tools\\Anaconda3\\lib\\site-packages\\pandas\\compat\\_optional.py", line 138, in import_optional_dependency\r\n    module = importlib.import_module(name)\r\n  File "C:\\tools\\Anaconda3\\lib\\importlib\\__init__.py", line 127, in import_module\r\n    return _bootstrap._gcd_import(name[level:], package, level)\r\n  File "<frozen importlib._bootstrap>", line 1030, in _gcd_import\r\n  File "<frozen importlib._bootstrap>", line 1007, in _find_and_load\r\n  File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked\r\n  File "<frozen importlib._bootstrap>", line 680, in _load_unlocked\r\n  File "<frozen importlib._bootstrap_external>", line 850, in exec_module\r\n  File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed\r\n  File "C:\\tools\\Anaconda3\\lib\\site-packages\\setuptools\\__init__.py", line 8, in <module>\r\n    import _distutils_hack.override  # noqa: F401\r\n  File "C:\\tools\\Anaconda3\\lib\\site-packages\\_distutils_hack\\override.py", line 1, in <module>\r\n    __import__(\'_distutils_hack\').do_override()\r\n  File "C:\\tools\\Anaconda3\\lib\\site-packages\\_distutils_hack\\__init__.py", line 72, in do_override\r\n    ensure_local_distutils()\r\n  File "C:\\tools\\Anaconda3\\lib\\site-packages\\_distutils_hack\\__init__.py", line 59, in ensure_local_distutils\r\n    assert \'_distutils\' in core.__file__, core.__file__\r\nAssertionError: C:\\tools\\Anaconda3\\lib\\distutils\\core.py\r\n\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48052/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48052/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48050',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48050/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48050/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48050/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48050',
#   'id': 1336561687,
#   'node_id': 'PR_kwDOAA0YD849Dt3t',
#   'number': 48050,
#   'title': 'ENH: allow user to infer SAS file encoding; add correct encoding names',
#   'user': {'login': 'YYYasin19',
#    'id': 26421646,
#    'node_id': 'MDQ6VXNlcjI2NDIxNjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26421646?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YYYasin19',
#    'html_url': 'https://github.com/YYYasin19',
#    'followers_url': 'https://api.github.com/users/YYYasin19/followers',
#    'following_url': 'https://api.github.com/users/YYYasin19/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/YYYasin19/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/YYYasin19/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/YYYasin19/subscriptions',
#    'organizations_url': 'https://api.github.com/users/YYYasin19/orgs',
#    'repos_url': 'https://api.github.com/users/YYYasin19/repos',
#    'events_url': 'https://api.github.com/users/YYYasin19/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/YYYasin19/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 258745163,
#     'node_id': 'MDU6TGFiZWwyNTg3NDUxNjM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20SAS',
#     'name': 'IO SAS',
#     'color': '5319e7',
#     'default': False,
#     'description': 'SAS: read_sas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-11T22:32:14Z',
#   'updated_at': '2022-08-13T10:38:37Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48050',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48050',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48050.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48050.patch',
#    'merged_at': None},
#   'body': '- [x] closes #48048 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48050/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48050/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48048',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48048/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48048/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48048/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48048',
#   'id': 1336561147,
#   'node_id': 'I_kwDOAA0YD85Pqk37',
#   'number': 48048,
#   'title': 'ENH: Add option to `read_sas` to infer encoding from file, then use encoding',
#   'user': {'login': 'YYYasin19',
#    'id': 26421646,
#    'node_id': 'MDQ6VXNlcjI2NDIxNjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26421646?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YYYasin19',
#    'html_url': 'https://github.com/YYYasin19',
#    'followers_url': 'https://api.github.com/users/YYYasin19/followers',
#    'following_url': 'https://api.github.com/users/YYYasin19/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/YYYasin19/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/YYYasin19/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/YYYasin19/subscriptions',
#    'organizations_url': 'https://api.github.com/users/YYYasin19/orgs',
#    'repos_url': 'https://api.github.com/users/YYYasin19/repos',
#    'events_url': 'https://api.github.com/users/YYYasin19/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/YYYasin19/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-11T22:31:20Z',
#   'updated_at': '2022-08-14T18:30:49Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\r\n\r\n- [X] Adding new functionality to pandas\r\n\r\n- [X] Changing existing functionality in pandas\r\n\r\n- [ ] Removing existing functionality in pandas\r\n\r\n\r\n### Problem Description\r\n\r\nCurrently, `pd.read_sas(f)` only accepts and `encoding` argument that is either the correct python encoding for the file or None, in which case the default encoding, here `utf-8`, will be used.\r\n\r\nThis requires the user to know in-before which encoding the file uses. Fixing this is straightforward since the current implementation already reads the current file encoding into `self.file_encoding`.\r\nHowever, this `self.file_encoding` is not used during decoding.\r\n\r\nAdditionally, the current encoding constants have incorrect names so they can\'t be used in python\'s `.decode` function. The correct names can be sampled by matching the [SAS documentation](https://support.sas.com/documentation/onlinedoc/dfdmstudio/2.6/dmpdmsug/Content/dfU_Encodings_SAS.html) with the [Python standard reference](https://docs.python.org/3/library/codecs.html#standard-encodings).\r\n\r\n### Feature Description\r\n\r\nTo not break backwards-compatibility I would add another option called `infer` to the encoding parameter, such that the interface would look like this:\r\n```py\r\ndf = pd.read_sas(f, encoding="infer")\r\n```\r\n\r\n### Alternative Solutions\r\n\r\nThe simplest alternative is to just know the file encoding of the sas file already and pass it as an argument.\r\n\r\n### Additional Context\r\n\r\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48048/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48048/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
df=pd.DataFrame(data1, columns=['url','repository_url','labels_url','user'])

# %%
df.to_csv('json_input.csv',index=False)

# %%
df2=pd.read_csv('json_input.csv')

# %%
df2
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'dataxerik', 'id': 15721311, 'node_i...
# 1   {'login': 'daspartho', 'id': 59410571, 'node_i...
# 2   {'login': 'robna', 'id': 26489593, 'node_id': ...
# 3   {'login': 'dannyi96', 'id': 15380498, 'node_id...
# 4   {'login': 'prhbrt', 'id': 7011110, 'node_id': ...
# 5   {'login': 'VladimirFokow', 'id': 57260995, 'no...
# 6   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 7   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 8   {'login': 'attack68', 'id': 24256554, 'node_id...
# 9   {'login': 'andreas-vester', 'id': 29901736, 'n...
# 10  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 11  {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 12  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 13  {'login': 'YagoGG', 'id': 7356565, 'node_id': ...
# 14  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 15  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 16  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 17  {'login': 'YagoGG', 'id': 7356565, 'node_id': ...
# 18  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 19  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 20  {'login': 'joshuabello2550', 'id': 43732414, '...
# 21  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 22  {'login': 'marenwestermann', 'id': 17019042, '...
# 23  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 24  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 25  {'login': 'jtho123', 'id': 111128123, 'node_id...
# 26  {'login': 'joshuabello2550', 'id': 43732414, '...
# 27  {'login': 'redreamality', 'id': 3147776, 'node...
# 28  {'login': 'YYYasin19', 'id': 26421646, 'node_i...
# 29  {'login': 'YYYasin19', 'id': 26421646, 'node_i...

# %%
df2.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'user'], dtype='object')

# %% [markdown]
# # 1> To split 'user' column dictionary, separate and store them into different columns and store it to csv file

# %%
df3=pd.concat([df2, df2['user'].apply(literal_eval).apply(pd.Series)], axis=1)

# %%
df3
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user               login  \
# 0   {'login': 'dataxerik', 'id': 15721311, 'node_i...           dataxerik
# 1   {'login': 'daspartho', 'id': 59410571, 'node_i...           daspartho
# 2   {'login': 'robna', 'id': 26489593, 'node_id': ...               robna
# 3   {'login': 'dannyi96', 'id': 15380498, 'node_id...            dannyi96
# 4   {'login': 'prhbrt', 'id': 7011110, 'node_id': ...              prhbrt
# 5   {'login': 'VladimirFokow', 'id': 57260995, 'no...       VladimirFokow
# 6   {'login': 'jbrockmendel', 'id': 8078968, 'node...        jbrockmendel
# 7   {'login': 'phofl', 'id': 61934744, 'node_id': ...               phofl
# 8   {'login': 'attack68', 'id': 24256554, 'node_id...            attack68
# 9   {'login': 'andreas-vester', 'id': 29901736, 'n...      andreas-vester
# 10  {'login': 'phofl', 'id': 61934744, 'node_id': ...               phofl
# 11  {'login': 'weikhor', 'id': 36619387, 'node_id'...             weikhor
# 12  {'login': 'mroeschke', 'id': 10647082, 'node_i...           mroeschke
# 13  {'login': 'YagoGG', 'id': 7356565, 'node_id': ...              YagoGG
# 14  {'login': 'rhshadrach', 'id': 45562402, 'node_...          rhshadrach
# 15  {'login': 'phofl', 'id': 61934744, 'node_id': ...               phofl
# 16  {'login': 'phofl', 'id': 61934744, 'node_id': ...               phofl
# 17  {'login': 'YagoGG', 'id': 7356565, 'node_id': ...              YagoGG
# 18  {'login': 'mroeschke', 'id': 10647082, 'node_i...           mroeschke
# 19  {'login': 'phofl', 'id': 61934744, 'node_id': ...               phofl
# 20  {'login': 'joshuabello2550', 'id': 43732414, '...     joshuabello2550
# 21  {'login': 'jbrockmendel', 'id': 8078968, 'node...        jbrockmendel
# 22  {'login': 'marenwestermann', 'id': 17019042, '...     marenwestermann
# 23  {'login': 'jorisvandenbossche', 'id': 1020496,...  jorisvandenbossche
# 24  {'login': 'jorisvandenbossche', 'id': 1020496,...  jorisvandenbossche
# 25  {'login': 'jtho123', 'id': 111128123, 'node_id...             jtho123
# 26  {'login': 'joshuabello2550', 'id': 43732414, '...     joshuabello2550
# 27  {'login': 'redreamality', 'id': 3147776, 'node...        redreamality
# 28  {'login': 'YYYasin19', 'id': 26421646, 'node_i...           YYYasin19
# 29  {'login': 'YYYasin19', 'id': 26421646, 'node_i...           YYYasin19
#
#            id               node_id  \
# 0    15721311  MDQ6VXNlcjE1NzIxMzEx
# 1    59410571  MDQ6VXNlcjU5NDEwNTcx
# 2    26489593  MDQ6VXNlcjI2NDg5NTkz
# 3    15380498  MDQ6VXNlcjE1MzgwNDk4
# 4     7011110  MDQ6VXNlcjcwMTExMTA=
# 5    57260995  MDQ6VXNlcjU3MjYwOTk1
# 6     8078968  MDQ6VXNlcjgwNzg5Njg=
# 7    61934744  MDQ6VXNlcjYxOTM0NzQ0
# 8    24256554  MDQ6VXNlcjI0MjU2NTU0
# 9    29901736  MDQ6VXNlcjI5OTAxNzM2
# 10   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 11   36619387  MDQ6VXNlcjM2NjE5Mzg3
# 12   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 13    7356565  MDQ6VXNlcjczNTY1NjU=
# 14   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 15   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 16   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 17    7356565  MDQ6VXNlcjczNTY1NjU=
# 18   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 19   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 20   43732414  MDQ6VXNlcjQzNzMyNDE0
# 21    8078968  MDQ6VXNlcjgwNzg5Njg=
# 22   17019042  MDQ6VXNlcjE3MDE5MDQy
# 23    1020496  MDQ6VXNlcjEwMjA0OTY=
# 24    1020496  MDQ6VXNlcjEwMjA0OTY=
# 25  111128123          U_kgDOBp-uOw
# 26   43732414  MDQ6VXNlcjQzNzMyNDE0
#
#                                     organizations_url  \
# 0         https://api.github.com/users/dataxerik/orgs
# 1         https://api.github.com/users/daspartho/orgs
# 2             https://api.github.com/users/robna/orgs
# 3          https://api.github.com/users/dannyi96/orgs
# 4            https://api.github.com/users/prhbrt/orgs
# 5     https://api.github.com/users/VladimirFokow/orgs
# 6      https://api.github.com/users/jbrockmendel/orgs
# 7             https://api.github.com/users/phofl/orgs
# 8          https://api.github.com/users/attack68/orgs
# 9    https://api.github.com/users/andreas-vester/orgs
# 10            https://api.github.com/users/phofl/orgs
# 11          https://api.github.com/users/weikhor/orgs
# 12        https://api.github.com/users/mroeschke/orgs
# 13           https://api.github.com/users/YagoGG/orgs
# 14       https://api.github.com/users/rhshadrach/orgs
# 15            https://api.github.com/users/phofl/orgs
# 16            https://api.github.com/users/phofl/orgs
# 17           https://api.github.com/users/YagoGG/orgs
# 18        https://api.github.com/users/mroeschke/orgs
# 19            https://api.github.com/users/phofl/orgs
# 20  https://api.github.com/users/joshuabello2550/orgs
# 21     https://api.github.com/users/jbrockmendel/orgs
# 22  https://api.github.com/users/marenwestermann/orgs
# 23  https://api.github.com/users/jorisvandenbossch...
# 24  https://api.github.com/users/jorisvandenbossch...
# 25          https://api.github.com/users/jtho123/orgs
# 26  https://api.github.com/users/joshuabello2550/orgs
# 27     https://api.github.com/users/redreamality/orgs
# 28        https://api.github.com/users/YYYasin19/orgs
# 29        https://api.github.com/users/YYYasin19/orgs
#
#                                             repos_url  \
# 0        https://api.github.com/users/dataxerik/repos
# 1        https://api.github.com/users/daspartho/repos
# 2            https://api.github.com/users/robna/repos
# 3         https://api.github.com/users/dannyi96/repos
# 4           https://api.github.com/users/prhbrt/repos
# 5    https://api.github.com/users/VladimirFokow/repos
# 6     https://api.github.com/users/jbrockmendel/repos
# 7            https://api.github.com/users/phofl/repos
# 8         https://api.github.com/users/attack68/repos
# 9   https://api.github.com/users/andreas-vester/repos
# 10           https://api.github.com/users/phofl/repos
# 11         https://api.github.com/users/weikhor/repos
# 12       https://api.github.com/users/mroeschke/repos
# 13          https://api.github.com/users/YagoGG/repos
# 14      https://api.github.com/users/rhshadrach/repos
# 15           https://api.github.com/users/phofl/repos
# 16           https://api.github.com/users/phofl/repos
# 17          https://api.github.com/users/YagoGG/repos
# 18       https://api.github.com/users/mroeschke/repos
# 19           https://api.github.com/users/phofl/repos
# 20  https://api.github.com/users/joshuabello2550/r...
# 21    https://api.github.com/users/jbrockmendel/repos
# 22  https://api.github.com/users/marenwestermann/r...
# 23  https://api.github.com/users/jorisvandenbossch...
# 24  https://api.github.com/users/jorisvandenbossch...
# 25         https://api.github.com/users/jtho123/repos
# 26  https://api.github.com/users/joshuabello2550/r...
# 27    https://api.github.com/users/redreamality/repos
# 28       https://api.github.com/users/YYYasin19/repos
# 29       https://api.github.com/users/YYYasin19/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/dataxerik/events{...
# 1   https://api.github.com/users/daspartho/events{...
# 2   https://api.github.com/users/robna/events{/pri...
# 3   https://api.github.com/users/dannyi96/events{/...
# 4   https://api.github.com/users/prhbrt/events{/pr...
# 5   https://api.github.com/users/VladimirFokow/eve...
# 6   https://api.github.com/users/jbrockmendel/even...
# 7   https://api.github.com/users/phofl/events{/pri...
# 8   https://api.github.com/users/attack68/events{/...
# 9   https://api.github.com/users/andreas-vester/ev...
# 10  https://api.github.com/users/phofl/events{/pri...
# 11  https://api.github.com/users/weikhor/events{/p...
# 12  https://api.github.com/users/mroeschke/events{...
# 13  https://api.github.com/users/YagoGG/events{/pr...
# 14  https://api.github.com/users/rhshadrach/events...
# 15  https://api.github.com/users/phofl/events{/pri...
# 16  https://api.github.com/users/phofl/events{/pri...
# 17  https://api.github.com/users/YagoGG/events{/pr...
# 18  https://api.github.com/users/mroeschke/events{...
# 19  https://api.github.com/users/phofl/events{/pri...
# 20  https://api.github.com/users/joshuabello2550/e...
# 21  https://api.github.com/users/jbrockmendel/even...
# 22  https://api.github.com/users/marenwestermann/e...
# 23  https://api.github.com/users/jorisvandenbossch...
# 24  https://api.github.com/users/jorisvandenbossch...
# 25  https://api.github.com/users/jtho123/events{/p...
# 26  https://api.github.com/users/joshuabello2550/e...
# 27  https://api.github.com/users/redreamality/even...
# 28  https://api.github.com/users/YYYasin19/events{...
# 29  https://api.github.com/users/YYYasin19/events{...
#
#                                   received_events_url  type site_admin
# 0   https://api.github.com/users/dataxerik/receive...  User      False
# 1   https://api.github.com/users/daspartho/receive...  User      False
# 2   https://api.github.com/users/robna/received_ev...  User      False
# 3   https://api.github.com/users/dannyi96/received...  User      False
# 4   https://api.github.com/users/prhbrt/received_e...  User      False
# 5   https://api.github.com/users/VladimirFokow/rec...  User      False
# 6   https://api.github.com/users/jbrockmendel/rece...  User      False
# 7   https://api.github.com/users/phofl/received_ev...  User      False
# 8   https://api.github.com/users/attack68/received...  User      False
# 9   https://api.github.com/users/andreas-vester/re...  User      False
# 10  https://api.github.com/users/phofl/received_ev...  User      False
# 11  https://api.github.com/users/weikhor/received_...  User      False
# 12  https://api.github.com/users/mroeschke/receive...  User      False
# 13  https://api.github.com/users/YagoGG/received_e...  User      False
# 14  https://api.github.com/users/rhshadrach/receiv...  User      False
# 15  https://api.github.com/users/phofl/received_ev...  User      False
# 16  https://api.github.com/users/phofl/received_ev...  User      False
# 17  https://api.github.com/users/YagoGG/received_e...  User      False
# 18  https://api.github.com/users/mroeschke/receive...  User      False
# 19  https://api.github.com/users/phofl/received_ev...  User      False
# 20  https://api.github.com/users/joshuabello2550/r...  User      False
# 21  https://api.github.com/users/jbrockmendel/rece...  User      False
# 22  https://api.github.com/users/marenwestermann/r...  User      False
# 23  https://api.github.com/users/jorisvandenbossch...  User      False
# 24  https://api.github.com/users/jorisvandenbossch...  User      False
# 25  https://api.github.com/users/jtho123/received_...  User      False
# 26  https://api.github.com/users/joshuabello2550/r...  User      False
# 27  https://api.github.com/users/redreamality/rece...  User      False
# 28  https://api.github.com/users/YYYasin19/receive...  User      False
# 29  https://api.github.com/users/YYYasin19/receive...  User      False
#
# [30 rows x 22 columns]
